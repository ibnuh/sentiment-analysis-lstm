# %% [markdown]
# # Sentiment Analysis on Twitter tweets using LSTM and Keras
# <hr>
#
# ### Steps
# <ol type="1">
#     <li>Load the dataset (13k twitter tweets with manually marked label)</li>
#     <li>Clean Dataset</li>
#     <li>Encode Sentiments</li>
#     <li>Split Dataset</li>
#     <li>Tokenize and Pad/Truncate Tweets</li>
#     <li>Build Architecture/Model</li>
#     <li>Train and Test</li>
# </ol>
#
# <hr>
# <i>Import all the libraries needed</i>

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
import pandas as pd    # to load dataset
import numpy as np     # for mathematic equation
from nltk.corpus import stopwords   # to get collection of stopwords
from sklearn.model_selection import train_test_split       # for splitting dataset
from tensorflow.keras.preprocessing.text import Tokenizer  # to encode text to int
from tensorflow.keras.preprocessing.sequence import pad_sequences   # to do padding or truncating
from tensorflow.keras.models import Sequential     # the model
from tensorflow.keras.layers import Embedding, LSTM, Dense # layers of the architecture
from tensorflow.keras.callbacks import ModelCheckpoint   # save model
from tensorflow.keras.models import load_model   # load saved model
import re, io, json
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory # Indonesian Stemmer

# %% [markdown]
# <hr>
# <i>Preview dataset</i>

# %%
data = pd.read_csv('utf8_dataset.csv')

print(data[['Tweet', 'HS']])
# Out:
#                                                    Tweet  HS
# 0      - disaat semua cowok berusaha melacak perhatia...   1
# 1      RT USER: USER siapa yang telat ngasih tau elu?...   0
# 2      41. Kadang aku berfikir, kenapa aku tetap perc...   0
# 3      USER USER AKU ITU AKU\n\nKU TAU MATAMU SIPIT T...   0
# 4      USER USER Kaum cebong kapir udah keliatan dong...   1
# ...                                                  ...  ..
# 13164  USER jangan asal ngomong ndasmu. congor lu yg ...   1
# 13165                       USER Kasur mana enak kunyuk'   0
# 13166  USER Hati hati bisu :( .g\n\nlagi bosan huft \...   0
# 13167  USER USER USER USER Bom yang real mudah terdet...   0
# 13168  USER Mana situ ngasih(": itu cuma foto ya kuti...   1
#
# [13169 rows x 2 columns]

# %% [markdown]
# <hr>
# <b>Stop Word</b> is a commonly used words in a sentence, usually a search engine is programmed to ignore this words (i.e. "the", "a", "an", "of", etc.)
#
# <i>Declaring the Indonesian stop words</i>

# %%
indonesian_stopwords = pd.read_csv('stopwords.txt', sep="\n")
indonesian_stopwords = indonesian_stopwords.iloc[:, 0].values.tolist()
indonesian_stopwords
# Out:
# ['adalah',
#  'adanya',
#  'adapun',
#  'agak',
#  'agaknya',
#  'agar',
#  'akan',
#  'akankah',
#  'akhir',
#  'akhiri',
#  'akhirnya',
#  'aku',
#  'akulah',
#  'amat',
#  'amatlah',
#  'anda',
#  'andalah',
#  'antar',
#  'antara',
#  'antaranya',
#  'apa',
#  'apaan',
#  'apabila',
#  'apakah',
#  'apalagi',
#  'apatah',
#  'artinya',
#  'asal',
#  'asalkan',
#  'atas',
#  'atau',
#  'ataukah',
#  'ataupun',
#  'awal',
#  'awalnya',
#  'bagai',
#  'bagaikan',
#  'bagaimana',
#  'bagaimanakah',
#  'bagaimanapun',
#  'bagi',
#  'bagian',
#  'bahkan',
#  'bahwa',
#  'bahwasanya',
#  'baik',
#  'bakal',
#  'bakalan',
#  'balik',
#  'banyak',
#  'bapak',
#  'baru',
#  'bawah',
#  'beberapa',
#  'begini',
#  'beginian',
#  'beginikah',
#  'beginilah',
#  'begitu',
#  'begitukah',
#  'begitulah',
#  'begitupun',
#  'bekerja',
#  'belakang',
#  'belakangan',
#  'belum',
#  'belumlah',
#  'benar',
#  'benarkah',
#  'benarlah',
#  'berada',
#  'berakhir',
#  'berakhirlah',
#  'berakhirnya',
#  'berapa',
#  'berapakah',
#  'berapalah',
#  'berapapun',
#  'berarti',
#  'berawal',
#  'berbagai',
#  'berdatangan',
#  'beri',
#  'berikan',
#  'berikut',
#  'berikutnya',
#  'berjumlah',
#  'berkali-kali',
#  'berkata',
#  'berkehendak',
#  'berkeinginan',
#  'berkenaan',
#  'berlainan',
#  'berlalu',
#  'berlangsung',
#  'berlebihan',
#  'bermacam',
#  'bermacam-macam',
#  'bermaksud',
#  'bermula',
#  'bersama',
#  'bersama-sama',
#  'bersiap',
#  'bersiap-siap',
#  'bertanya',
#  'bertanya-tanya',
#  'berturut',
#  'berturut-turut',
#  'bertutur',
#  'berujar',
#  'berupa',
#  'besar',
#  'betul',
#  'betulkah',
#  'biasa',
#  'biasanya',
#  'bila',
#  'bilakah',
#  'bisa',
#  'bisakah',
#  'boleh',
#  'bolehkah',
#  'bolehlah',
#  'buat',
#  'bukan',
#  'bukankah',
#  'bukanlah',
#  'bukannya',
#  'bulan',
#  'bung',
#  'cara',
#  'caranya',
#  'cukup',
#  'cukupkah',
#  'cukuplah',
#  'cuma',
#  'dahulu',
#  'dalam',
#  'dan',
#  'dapat',
#  'dari',
#  'daripada',
#  'datang',
#  'dekat',
#  'demi',
#  'demikian',
#  'demikianlah',
#  'dengan',
#  'depan',
#  'di',
#  'dia',
#  'diakhiri',
#  'diakhirinya',
#  'dialah',
#  'diantara',
#  'diantaranya',
#  'diberi',
#  'diberikan',
#  'diberikannya',
#  'dibuat',
#  'dibuatnya',
#  'didapat',
#  'didatangkan',
#  'digunakan',
#  'diibaratkan',
#  'diibaratkannya',
#  'diingat',
#  'diingatkan',
#  'diinginkan',
#  'dijawab',
#  'dijelaskan',
#  'dijelaskannya',
#  'dikarenakan',
#  'dikatakan',
#  'dikatakannya',
#  'dikerjakan',
#  'diketahui',
#  'diketahuinya',
#  'dikira',
#  'dilakukan',
#  'dilalui',
#  'dilihat',
#  'dimaksud',
#  'dimaksudkan',
#  'dimaksudkannya',
#  'dimaksudnya',
#  'diminta',
#  'dimintai',
#  'dimisalkan',
#  'dimulai',
#  'dimulailah',
#  'dimulainya',
#  'dimungkinkan',
#  'dini',
#  'dipastikan',
#  'diperbuat',
#  'diperbuatnya',
#  'dipergunakan',
#  'diperkirakan',
#  'diperlihatkan',
#  'diperlukan',
#  'diperlukannya',
#  'dipersoalkan',
#  'dipertanyakan',
#  'dipunyai',
#  'diri',
#  'dirinya',
#  'disampaikan',
#  'disebut',
#  'disebutkan',
#  'disebutkannya',
#  'disini',
#  'disinilah',
#  'ditambahkan',
#  'ditandaskan',
#  'ditanya',
#  'ditanyai',
#  'ditanyakan',
#  'ditegaskan',
#  'ditujukan',
#  'ditunjuk',
#  'ditunjuki',
#  'ditunjukkan',
#  'ditunjukkannya',
#  'ditunjuknya',
#  'dituturkan',
#  'dituturkannya',
#  'diucapkan',
#  'diucapkannya',
#  'diungkapkan',
#  'dong',
#  'dua',
#  'dulu',
#  'empat',
#  'enggak',
#  'enggaknya',
#  'entah',
#  'entahlah',
#  'guna',
#  'gunakan',
#  'hal',
#  'hampir',
#  'hanya',
#  'hanyalah',
#  'hari',
#  'harus',
#  'haruslah',
#  'harusnya',
#  'hendak',
#  'hendaklah',
#  'hendaknya',
#  'hingga',
#  'ia',
#  'ialah',
#  'ibarat',
#  'ibaratkan',
#  'ibaratnya',
#  'ibu',
#  'ikut',
#  'ingat',
#  'ingat-ingat',
#  'ingin',
#  'inginkah',
#  'inginkan',
#  'ini',
#  'inikah',
#  'inilah',
#  'itu',
#  'itukah',
#  'itulah',
#  'jadi',
#  'jadilah',
#  'jadinya',
#  'jangan',
#  'jangankan',
#  'janganlah',
#  'jauh',
#  'jawab',
#  'jawaban',
#  'jawabnya',
#  'jelas',
#  'jelaskan',
#  'jelaslah',
#  'jelasnya',
#  'jika',
#  'jikalau',
#  'juga',
#  'jumlah',
#  'jumlahnya',
#  'justru',
#  'kala',
#  'kalau',
#  'kalaulah',
#  'kalaupun',
#  'kalian',
#  'kami',
#  'kamilah',
#  'kamu',
#  'kamulah',
#  'kan',
#  'kapan',
#  'kapankah',
#  'kapanpun',
#  'karena',
#  'karenanya',
#  'kasus',
#  'kata',
#  'katakan',
#  'katakanlah',
#  'katanya',
#  'ke',
#  'keadaan',
#  'kebetulan',
#  'kecil',
#  'kedua',
#  'keduanya',
#  'keinginan',
#  'kelamaan',
#  'kelihatan',
#  'kelihatannya',
#  'kelima',
#  'keluar',
#  'kembali',
#  'kemudian',
#  'kemungkinan',
#  'kemungkinannya',
#  'kenapa',
#  'kepada',
#  'kepadanya',
#  'kesampaian',
#  'keseluruhan',
#  'keseluruhannya',
#  'keterlaluan',
#  'ketika',
#  'khususnya',
#  'kini',
#  'kinilah',
#  'kira',
#  'kira-kira',
#  'kiranya',
#  'kita',
#  'kitalah',
#  'kok',
#  'kurang',
#  'lagi',
#  'lagian',
#  'lah',
#  'lain',
#  'lainnya',
#  'lalu',
#  'lama',
#  'lamanya',
#  'lanjut',
#  'lanjutnya',
#  'lebih',
#  'lewat',
#  'lima',
#  'luar',
#  'macam',
#  'maka',
#  'makanya',
#  'makin',
#  'malah',
#  'malahan',
#  'mampu',
#  'mampukah',
#  'mana',
#  'manakala',
#  'manalagi',
#  'masa',
#  'masalah',
#  'masalahnya',
#  'masih',
#  'masihkah',
#  'masing',
#  'masing-masing',
#  'mau',
#  'maupun',
#  'melainkan',
#  'melakukan',
#  'melalui',
#  'melihat',
#  'melihatnya',
#  'memang',
#  'memastikan',
#  'memberi',
#  'memberikan',
#  'membuat',
#  'memerlukan',
#  'memihak',
#  'meminta',
#  'memintakan',
#  'memisalkan',
#  'memperbuat',
#  'mempergunakan',
#  'memperkirakan',
#  'memperlihatkan',
#  'mempersiapkan',
#  'mempersoalkan',
#  'mempertanyakan',
#  'mempunyai',
#  'memulai',
#  'memungkinkan',
#  'menaiki',
#  'menambahkan',
#  'menandaskan',
#  'menanti',
#  'menanti-nanti',
#  'menantikan',
#  'menanya',
#  'menanyai',
#  'menanyakan',
#  'mendapat',
#  'mendapatkan',
#  'mendatang',
#  'mendatangi',
#  'mendatangkan',
#  'menegaskan',
#  'mengakhiri',
#  'mengapa',
#  'mengatakan',
#  'mengatakannya',
#  'mengenai',
#  'mengerjakan',
#  'mengetahui',
#  'menggunakan',
#  'menghendaki',
#  'mengibaratkan',
#  'mengibaratkannya',
#  'mengingat',
#  'mengingatkan',
#  'menginginkan',
#  'mengira',
#  'mengucapkan',
#  'mengucapkannya',
#  'mengungkapkan',
#  'menjadi',
#  'menjawab',
#  'menjelaskan',
#  'menuju',
#  'menunjuk',
#  'menunjuki',
#  'menunjukkan',
#  'menunjuknya',
#  'menurut',
#  'menuturkan',
#  'menyampaikan',
#  'menyangkut',
#  'menyatakan',
#  'menyebutkan',
#  'menyeluruh',
#  'menyiapkan',
#  'merasa',
#  'mereka',
#  'merekalah',
#  'merupakan',
#  'meski',
#  'meskipun',
#  'meyakini',
#  'meyakinkan',
#  'minta',
#  'mirip',
#  'misal',
#  'misalkan',
#  'misalnya',
#  'mula',
#  'mulai',
#  'mulailah',
#  'mulanya',
#  'mungkin',
#  'mungkinkah',
#  'nah',
#  'naik',
#  'namun',
#  'nanti',
#  'nantinya',
#  'nyaris',
#  'nyatanya',
#  'oleh',
#  'olehnya',
#  'pada',
#  'padahal',
#  'padanya',
#  'pak',
#  'paling',
#  'panjang',
#  'pantas',
#  'para',
#  'pasti',
#  'pastilah',
#  'penting',
#  'pentingnya',
#  'per',
#  'percuma',
#  'perlu',
#  'perlukah',
#  'perlunya',
#  'pernah',
#  'persoalan',
#  'pertama',
#  'pertama-tama',
#  'pertanyaan',
#  'pertanyakan',
#  'pihak',
#  'pihaknya',
#  'pukul',
#  'pula',
#  'pun',
#  'punya',
#  'rasa',
#  'rasanya',
#  'rata',
#  'rupanya',
#  'saat',
#  'saatnya',
#  'saja',
#  'sajalah',
#  'saling',
#  'sama',
#  'sama-sama',
#  'sambil',
#  'sampai',
#  'sampai-sampai',
#  'sampaikan',
#  'sana',
#  'sangat',
#  'sangatlah',
#  'satu',
#  'saya',
#  'sayalah',
#  'se',
#  'sebab',
#  'sebabnya',
#  'sebagai',
#  'sebagaimana',
#  'sebagainya',
#  'sebagian',
#  'sebaik',
#  'sebaik-baiknya',
#  'sebaiknya',
#  'sebaliknya',
#  'sebanyak',
#  'sebegini',
#  'sebegitu',
#  'sebelum',
#  'sebelumnya',
#  'sebenarnya',
#  'seberapa',
#  'sebesar',
#  'sebetulnya',
#  'sebisanya',
#  'sebuah',
#  'sebut',
#  'sebutlah',
#  'sebutnya',
#  'secara',
#  'secukupnya',
#  'sedang',
#  'sedangkan',
#  'sedemikian',
#  'sedikit',
#  'sedikitnya',
#  'seenaknya',
#  'segala',
#  'segalanya',
#  'segera',
#  'seharusnya',
#  'sehingga',
#  'seingat',
#  'sejak',
#  'sejauh',
#  'sejenak',
#  'sejumlah',
#  'sekadar',
#  'sekadarnya',
#  'sekali',
#  'sekali-kali',
#  'sekalian',
#  'sekaligus',
#  'sekalipun',
#  'sekarang',
#  'sekarang',
#  'sekecil',
#  'seketika',
#  'sekiranya',
#  'sekitar',
#  'sekitarnya',
#  'sekurang-kurangnya',
#  'sekurangnya',
#  'sela',
#  'selain',
#  'selaku',
#  'selalu',
#  'selama',
#  'selama-lamanya',
#  'selamanya',
#  'selanjutnya',
#  'seluruh',
#  'seluruhnya',
#  'semacam',
#  'semakin',
#  'semampu',
#  'semampunya',
#  'semasa',
#  'semasih',
#  'semata',
#  'semata-mata',
#  'semaunya',
#  'sementara',
#  'semisal',
#  'semisalnya',
#  'sempat',
#  'semua',
#  'semuanya',
#  'semula',
#  'sendiri',
#  'sendirian',
#  'sendirinya',
#  'seolah',
#  'seolah-olah',
#  'seorang',
#  'sepanjang',
#  'sepantasnya',
#  'sepantasnyalah',
#  'seperlunya',
#  'seperti',
#  'sepertinya',
#  'sepihak',
#  'sering',
#  'seringnya',
#  'serta',
#  'serupa',
#  'sesaat',
#  'sesama',
#  'sesampai',
#  'sesegera',
#  'sesekali',
#  'seseorang',
#  'sesuatu',
#  'sesuatunya',
#  'sesudah',
#  'sesudahnya',
#  'setelah',
#  'setempat',
#  'setengah',
#  'seterusnya',
#  'setiap',
#  'setiba',
#  'setibanya',
#  'setidak-tidaknya',
#  'setidaknya',
#  'setinggi',
#  'seusai',
#  'sewaktu',
#  'siap',
#  'siapa',
#  'siapakah',
#  'siapapun',
#  'sini',
#  'sinilah',
#  'soal',
#  'soalnya',
#  'suatu',
#  'sudah',
#  'sudahkah',
#  'sudahlah',
#  'supaya',
#  'tadi',
#  'tadinya',
#  'tahu',
#  'tahun',
#  'tak',
#  'tambah',
#  'tambahnya',
#  'tampak',
#  'tampaknya',
#  'tandas',
#  'tandasnya',
#  'tanpa',
#  'tanya',
#  'tanyakan',
#  'tanyanya',
#  'tapi',
#  'tegas',
#  'tegasnya',
#  'telah',
#  'tempat',
#  'tengah',
#  'tentang',
#  'tentu',
#  'tentulah',
#  'tentunya',
#  'tepat',
#  'terakhir',
#  'terasa',
#  'terbanyak',
#  'terdahulu',
#  'terdapat',
#  'terdiri',
#  'terhadap',
#  'terhadapnya',
#  'teringat',
#  'teringat-ingat',
#  'terjadi',
#  'terjadilah',
#  'terjadinya',
#  'terkira',
#  'terlalu',
#  'terlebih',
#  'terlihat',
#  'termasuk',
#  'ternyata',
#  'tersampaikan',
#  'tersebut',
#  'tersebutlah',
#  'tertentu',
#  'tertuju',
#  'terus',
#  'terutama',
#  'tetap',
#  'tetapi',
#  'tiap',
#  'tiba',
#  'tiba-tiba',
#  'tidak',
#  'tidakkah',
#  'tidaklah',
#  'tiga',
#  'tinggi',
#  'toh',
#  'tunjuk',
#  'turut',
#  'tutur',
#  'tuturnya',
#  'ucap',
#  'ucapnya',
#  'ujar',
#  'ujarnya',
#  'umum',
#  'umumnya',
#  'ungkap',
#  'ungkapnya',
#  'untuk',
#  'usah',
#  'usai',
#  'waduh',
#  'wah',
#  'wahai',
#  'waktu',
#  'waktunya',
#  'walau',
#  'walaupun',
#  'wong',
#  'yaitu',
#  'yakin',
#  'yakni',
#  'yang']

# %% [markdown]
# <hr>
#
# ### Load and Clean Dataset
#
# In the original dataset, the tweets are still dirty. There are still html tags, numbers, uppercase, and punctuations. This will not be good for training, so in <b>load_dataset()</b> function, beside loading the dataset using <b>pandas</b>, I also pre-process the tweets by removing html tags, non alphabet (punctuations and numbers), stop words, and lower case all of the tweets.
#
# ### Encode Sentiments
# In the same function, I also encode the sentiments into integers (0 and 1). Where 0 is for negative sentiments and 1 is for positive sentiments.

# %%
def stemmer(text):
    # Init indonesian stemmer
    factory = StemmerFactory()
    s = factory.create_stemmer()
    result = s.stem(text)
    print(result)
    

def load_dataset():
    df = pd.read_csv('utf8_dataset.csv')
    df.replace(to_replace=[r"\\t|\\n|\\r", "\t|\n|\r"], value=[" "," "], regex=True, inplace=True)

    x_data = df['Tweet']       # Tweets/Input
    y_data = df['HS']    # Sentiment/Output

    # PRE-PROCESS TWEETS
    x_data = x_data.apply(lambda tweet: tweet.lower())   # lower case
    x_data = x_data.replace({'<.*?>': ''}, regex = True)          # remove html tag
    x_data = x_data.replace({'[^A-Za-z]': ' '}, regex = True)     # remove non alphabet
    x_data = x_data.apply(lambda tweet: ' '.join([w for w in tweet.split() if len(w) > 2]))  # remove words that is lees than 2 chars
    x_data = x_data.str.replace('rt', '') # Remove RT
    x_data = x_data.str.replace('user', '') # Remove USER
    x_data = x_data.apply(lambda tweet: ' '.join(tweet.split()))   # Remove excess spaces
    x_data = x_data.str.strip() # Trim
    
    x_data = x_data.apply(lambda tweet: stemmer(tweet))   # stem
    
#     x_data = x_data.apply(lambda tweet: ' '.join([w for w in tweet.split() if w not in indonesian_stopwords]))  # remove stop words
    
    # ENCODE SENTIMENT -> 0 & 1
    y_data = y_data.replace(1, 1)
    y_data = y_data.replace(0, 0)

    return x_data, y_data

x_data, y_data = load_dataset()

print('Tweet')
print(x_data, '\n')
print('HS')
print(y_data)
# Out:
# saat semua cowok usaha lacak perhati gue loe lantas remeh perhati gue kasih khusus elo basic elo cowok bego
# siapa yang telat ngasih tau elu edan sarap gue gaul dengan cigax jifla cal sama siapa noh licew juga
# kadang aku berfikir kenapa aku tetap percaya pada tuhan padahal aku selalu jatuh kali kali kadang aku rasa tuhan itu ninggalkan aku sendiri ketika orangtuaku rencana pisah ketika kakak lebih pilih jadi kristen ketika aku anak ter
# aku itu aku tau mata sipit tapi liat dari mana itu aku
# kaum cebong kapir udah liat dongok dari awal tambah dongok lagi hahahah
# bani taplak dkk
# deklarasi pilkada aman dan anti hoax warga dukuh sari jabon
# gue baru aja kelar watch aldnoah zero paling kampret emang endingnya karakter utama cowonya kena friendzone bray url
# nah admin belanja satu lagi po baik nak makan ais kepal milo ais kepal horlicks atau cendol toping kaw kaw doket mano gerai rojak meuaku taipan depan twins baby amp romantika bank islam senawang
# enak klo smbil ngewe
# tidak punya jari tengah buat bom ukur nyali sama bacot
# banci kaleng malu bisa jawab peanyaan kami dari hari lalu nyungsep koe url
# kalo ajar ekonomi mesti jago privatisasi hati orang duh ironi
# aktor huruhara prabowo ingin lengser perintah jokowi nyata
# guru enak jadi jablay atau guru esde sih kayak nikmat jadi pecun ini guru
# lawan bicara gak intelek kyk loe otak gak punya ttg kencing onta aku hadis nabi dan itu sahih kafir kyk loe pasti tolak makanya loe ahlunnar
# belakang ini kok fikiran ampas banget
# ari sarua bek mah repeh monyet
# jadi cowo itu harus gantle kalo gantle itu nama banci
# slga mnr bom
# asw tapi gua jarang ngambek tacut wkkwkwkwkw gua kan bucin
# kalo kamu noob pasti peluang disakitin nya lebih gede
# joko widodo nilai bagai presiden lemah dalam sejarah indonesia hal ini jadi bukan saja karena jokowi tidak milik modal dukung politik yang cukup lain juga karena ketidakmampuan perintah hadap situasi ekonomi
# ajar sma kec bilah hilir deklarasi anti hoax amp pilkada damai
# bandara udara internasional keajati bangun oleh gubernur ahmad heryawan tanpa guna apbn perintah pusat insya allah siap operasi bulan depan
# siapa gubernur dan presiden rakyat kita juga
# ini kerja delay mulu setan
# turut pintu sorga ada yaitu pintu sorga yang asli dan pintu hati modusbanget
# pki hanya muncul jika jelang pilih kepala daerah dan pilih presiden krn goreng sampai gosong
# itu mah sdh nenek nenek heran sama cebong biasay bohong terus
# islam nusantara produk jil pasar gencar oleh antek jil sementara jil anti arab tapi pro aseng kata alm hasyim muzadi
# dari habis sahur sampe jam sibayik udah nete skg rasa lemas tak kira
# gak kak emak mah gak demen ama yang sipit wkwk
# laku homok jaman now ngentot aja sambil live blued gayvid gvid lokalhangat url
# kak gua bukan orang jawa maaf yak gua orang palembang soal kakak aja deh ajar aksara jawa atau kalak mau ajar budaya palembang
# pegawai guardian training lagi kek mentang gue kek gembel cuman kaos sama flat shoes nanya dijutekin bangsad emang males beli juga kabur gua matahari
# dpara bajing yang telah luka lady harus terima ganjar ratus kali lipat sanji hbd thpelautjkt
# aja tolak berita hoax dan sukses pilkada wilayah kota keidri
# presiden jokowi luarbiasa kerja nya tulus ihlas untuk rakyatb rsamajkw
# edan emang goollnya fabiano
# gapernah dalam quran bang pantesan mulut kaya orang kafir bejat hina farhatabbaslaw
# sangat lihat beda sekali wibawa sangat wibawa cuma gubernur indonesia massya allah
# anjir baru kali ini lihat orang bego mau debat pilkada kerja nyerang karakter shame you mpok silvy and agus debatfinalpilkadajkt
# gubernurzamannow gusipulputi ganjaryasin djarotsihar hasananton kosterace nurdinsudirman karolingidot keanekaragaman budaya suku agama itu sungguh kaya kita tutur djarot hadap pesea rakercabsu
# apa iya islam itu boleh lokalisasi lha kristen aja mas ada nusantara mas liat aja gereja bandung ada pake gamelan dan ada khotbah pake bhs sunda jawa ada hkbp juga kurang nusantara apa
# cipta situasi kamtibmas jelang pilkada kapolsek konang silaturahmi tokoh masyarakat
# positif kok positif respon masyarakat hadap cangkul impor garam impor beras impor jagung impor tenaga kerja impor esemka impor url
# kata sembahyang adopsi tradisi lokal pada masa kerja hindu istilah sembahyang pun lahir dari tradisi ritus menyembahhyang yang tunggal sama dengan shalat sembah all
# kau dik tinggi tapi bodoh ada larang bawa agama biar orang islam bayar ahok sadar jadi milih ahok gla
# btp the best abai kaum kampret otak micin
# otak tempurung mah usah ladenin smkn lawan makin bloon dan dungu dan kalo gitu dia makan hehe
# awaasss jgn sampe berita sampe akh gerung ntar susah nyari kosakatany klu bcr aja micingin mata bibir monyong samping suara keluar nhn kentut politik kotor skl jmn ini klu tahu b ini plng sambil nhn ngeden dungu
# pinokio umur taonan tuh gantipresiden
# cerita silat lae macam kho ping hoo yang dari indonesia tapi liang shen tulis dari china
# benci sekali dgn umat islam
# provokasi mayat politisasi agama sebab kalah pilkada dki begini cara cebong deskripsi kalah junjung fyi ahog blm pernah ikut pilih apa kec wakil dan dia bukan etnis mayorita
# dari pada gua nete
# lol bani lowo
# takabur bisa lahir dari siapa saja kuasa rakyat ulama maupun cendikia bahkan iblis mahluq alim amp telah ibadah atus laknat krn hasud takabburnya apalagi hanya orang ahli ilmu filsafat tdk failosof mari kita demo diri sendi
# orang yang suka konser konser sedikit boros
# sampai kapan makan racun banyak ulama yang kata hukum rokok mubah dan ada juga
# susilo bambang yudhoyono presiden minta khofifah emil untuk dekat dengan masyarakat bisa baguss khofifahemilnomer
# udah biasa kali gue kpoper tapi kalo ngomonv sama temen gue idol gua banci homo
# saya suka video url awal kisah seteru haji bolot amp malih tongtong
# budaya kafir sungguh klau hal islam tidak diendahkan
# hmm semua diam semua bisu kita coba tanya sama rumput goyang xab xab xab xaa xaa xaa
# apabila setan bisik was was kepada minta lindung kepada allah raf dan fushilat
# klw ente atheis ngapain sibuk dgn agama orang
# lengser jokowi bangsat
# selamat hari kain gantipresiden presidenbaru
# bajing homo hati hadap anak kita utama kamar mandi laki jgn biar sendiri url
# iya cocot
# karena budaya indonesia
# yang ngajarin solat ajah itu orang aseng dia hanya ingin pecah belah islam
# ngomong aja kaga bener bangke
# kita semua tidak pernah akan percaya negara kita suatu hari nanti akan jajah oleh rana dapat kes bubar sistem beraja negara kita kini untuk jadi bagai negara republik komunis padahal negara jaja
# tapi masih nikmat bijak yang dulu usul pki lha opo
# kalo umpama orang cina usir paksa dari indonesia gimana
# bunda ngentot yuk
# china babi china maling usirchina https hiwhjp
# bung karno anti asing dan beliau dari jawa coba deh adain konsensus lebih banyak mana jawa yang anti asing atau pro asing karena kebo ohannya kalau kami keliru kami tutup akun
# proyek korupsi rezim sby url
# wajar saja lihat saja tingkah bbrp petinggi negeri ini suka campur bhs indonesia dgn bhs asing tiap kali bicara
# pribadi senang kompetisi dalam hal yang baik dan positif
# terus turut kitab suci agama apa bilang mendadakkalap
# suka nutup mata kaga tutup pun udah lihat teutup gara sipit
# sbg muslim tdk rasa pak nista kitab suci alqur krn dlm alqur sndri ada bbrp suku kata smpai dtik ini blm tahu mkna faktual olh umat islam kami yakin kata tsb ada makna sirat fiksi blm
# kasar kau kampang
# bentar lagi gua rilis album the onta wkwkwkwkwk
# ada cebong bang dia rasa paling benar
# najis banget ngetwit apa barusan wey
# kamu transgender atau gmn anjing url
# awas bintit ngintipin titit kucing
# bawel baper bolot baik bodor gaje wkwk apa udah itu aja deh
# gue saranin perlu bnyk bacot maling ayat langsung the point aja jadi orang tdk paham teriakin aja kafir sesat liberal puja dukun bla blaaa pasti hati puas dehh
# jgn salah target bkn ahok agenda utama lengser jokowi
# masa baru kena hestek aja udah panas kepo banget gantipresiden
# maju sini duit tapi kau goyang kaki tak buat pape mana duit nak maju kat kau bodo url
# hkbp diri itu sejak pecah kristen khatolik pada zaman jajah belanda tdk ada nama kristen protestan ada kristen khatolik jadi pecah dan diri hkbp pama kali tarutung nah skrg anda
# banyak baca biar pintar jepang amerika china utang sama siapa anda tau enggak
# prabowo sudah kalah sebut bantu jokowi hanya citra adalah ratap pilu
# dan yang takut dengan adzan adalah iblis
# goblog itu adalah bani cebong tukang tipu jilat kuasa tahu gerakin masa bayar pakai nasi bungkus propaganda nasi bungkus memang selalu gagal
# wuih cebong sewot
# gera ini tekan penting kerja keras cara total untuk tingkat potensi bangsa
# padahal gubernur saat ini djarot mayoritas paai politik dprd juga dukung ahok djarot payah mereka url
# rezim rusak bukan baik systeamnya malah sibuk cari salah klu itu pasti ketemu aja kpk alat besok perintah ganti ulang kembali engah pernah selesai siapa organisasi orang
# saat orang orang saling tuding antek aseng aseng sungguh beepuk tangan
# nah loh kata anti aseng
# selamat pak moga bisa terus kiprah bahkan tingkat nasional
# asyikm nang saya sih ikut ulama saja
# yang saya tahu bahwa ketapang banyak tka asing kerja bagai usaha masuk who tambang bouksid viral saat pilpres dulu dan bisa jadi ini karena kerja sama tsb jadi era gubernur cornelis dan wakil ora
# anak pecun jauh hobi zina haha
# que bom sbbsnsn
# istirahat aja pak presiden momentum sudah lalu saya pernah jadi saksi telinga dan mata awal rapat bentuk pacitan tahun
# pada house select committee assassinations hsca temu cacat investigasi yang laku fbi dan warren commission hsca juga simpul ada empat tembak yang laku dan mungkin dapat konspirasi dalam
# tak asa genap tahun datang april akan gelar hajat pilpres acara tahun negara indonesia untuk pilih presiden moga senantiasa jalan aman dan lancar amin
# ian pantat
# ngakunya org pintar dan agama emang agama mana boleh nista dan hujat org lain jgnkan orang bodoh org maaf sejak lahir idiot sekalipun dia kita hrs hargain bagai sama cipta tuhan ingat iblis itu juga pintar dan sangat licik
# daftar capres untuk pilpres saja belum buka sampai agustus yang normatif begini politikus pdip masih belum paham gantipresiden
# tolol udah tau perintah rezim komunis ini bobrok koruptor bisa pimpin sidang dpr paya cebong url
# dari dulu kenapa bapak kalau mantan mantan selalu mgerasa sedih ampe pikir dan gabisa tidur lohh dan ngerasa jadi anak brengsek aja laki
# cina usak bangsa usir stuju
# gantipresiden scra konstitusional hak tiap rakyat woiii gin nih kalo planga plongo tapi laku otoriter
# mari kita wujud pilkada kota bengkulu aman dan damai cok adem heru
# mau tanya serius ini presiden jokowi knp ada islam nusantara knp tdk ada kristen nusantara budha hindu bahkan kong huchu nusantara
# korsa nyata moeldoko bukti istana takut dengan bangkit umat islam
# cowo yang jago drasex mana sini ngentot sama adek luvian
# kroasia itu kapir tauuu ngapain blajar kapir udh lupa kapling sorga
# loh bukan nya tri suhao ada homo
# gue tau loh bukan yang dulu yang masih culun dan cemen semua orang pasti akan ubah perlahan entah itu baik buruk
# pada perang salib dulu itu raja afrika bagi dua yakni babilonia peluk kristen dan tobaco peluk islam
# kejar setorang memang cukup bangsad mana rupiah turun
# moga ini ada tindak lanjut lapor hadap nista agama ade armando akan laku langsung oleh ketua umum fpi shobri lubis bareskrim mabes polri gambir jakaa pusat pada selasa pukul wib perhaps
# bangke hajar
# onta mati klo banyak minum
# url ahok tng mrka trus was was hdpnya
# itu baru sul teng ini ekses akibat sandera hutang china gantipresiden presidenbaru tetapjokowiganti
# pride yunani xbd xcf xce xcf xce xcf xce xce xbd xce xaf xce hyper phania angkuh harga diri sombong kenal juga dengan sebut hubris vanity harga diri yang tinggi dapat rubah manusia sombong sombong buat manusia kutuk mata tuhan dan dapat buat manusia cinta diri sendiri
# aku bea tuju pada hati logika jawab tapi hati tak tenang aku bea pada logika hati sedih cari jawab dalam wasiat beliau tinggal dan aku mulai jadi asing dan asing mata manusia tak apa duhai diri ada
# tak hanya kurang beaji nya kpk era ini tapi era ini juga komitmen dlm berantas korupsi tdk spt era pak sby
# admin tolol paai tolol paai tolol untuk orang tolol
# ayu ting ting goyang hot dekat raffi ahmad nagita slavina kampung norak url
# video ttg tka buat oleh malaysia tapi kutip nyata saya
# ppp jangan buru buru tolak wacana pilkada lewat dprd
# random pagi ada bapak nyamperin meja kerja trus nanya pake bedak apa sih biar muka bersih istri saya butek soal ingin jawab pake air wudhu tapi kristen
# gua kampret
# memek lonte ken sodok kontol gede
# jokowi aja mundur tutup url
# ngomong opo itu mulut kok pei banci beli kaca dulu lihat diri broo
# ada amin ras ada amat dan ada ratna paiiit ada onta ada lobang anus jdi jngan takut habis obat tenang
# tunggu komando imam bejat cabul taik beer xba ape bawa ulama dasar banj sempak
# kabinet beranta pecah belah satu hanya rezim ini
# dih ngaku lebih pinter orang politik ngaca dulu woyy tampang loe aja orang bego ckakakakak
# pdiperjuanganmenang dengan tekan usaha tambang dgn target proyek yang impossible lalu lelang murah pada antek cina ntb contoh kasus pdip mau menang dasar bajing
# caya sama mulut buaya bwang
# jika sby prabowo satu lawan mega jokowi maka peristiwa akan ulang mana pdip incumbent kalah mutlak oleh sby jkw mega sby lawan prabowo pilpres selesai sudah poros pilpres salah satu lawan
# jangan kayak banci kaleng kamu gatot sering buat gaduh gentleman lah mundur siap saing pilih presidens lawan jokowi
# bebal
# yang akhir karena indonesia negara dengan populasi muslim besar dunia yang mana islam saat ini rupa musuh barat amp komunis karena dapat hambat agenda dan penting mereka obviously
# umuh persib persib kunyuk
# buat film muslim pilih ahok mati nggak sholatin jamin laris
# tapi banu banu yahudi itu tentu beda dgn banu banu kristen syriac salah satu beda banu yahudi tetep pake eloah elohim yahwe sedang syriac sudah pake alah allah
# kenapa muka merah tak dpt cendol bukan setan cuaca skrg panas
# berita saracen diframing katak akan tim prabowo dan anies sandi seberulnya itu media tumpah sakit hati katak dan cebong ehe
# giat bhabinkamtibmas brigpol mbs sihombing hari ini rabu april melaks sambang desa dan tatap muka sekaligus monitoring kamtibmas tuju pilkada desa lobusiregar tepat rumah rudi panjaitan helm siahaan dan hotman siahaan
# syg bgt ngeliat perempuan kyk gin gak ada status apa udah nemplok laki laki sana sini haduh nagita slavina blak blakan sebut ayu ting ting kampung viva url
# jgn lupa juga kang umat katolik dan minorutas lain diperhatika gubernur untuk semua golong bukan satu golong
# kan ane bukan cebong udeh dibilangin dari maren masih ngeyel situ maksa ane jadi cebong
# lemah gerindra itu ada orang ini prabowo turun elektabilitasnya karena congor fadlizon spt durno
# selamat hari kain tiap kali selalu raya lalu apa makna kali ini
# foto memang bisu tpi milik banyak ai sush diaikan sma pei kamu susah diaikan mau putus atau lanjut
# wakakakaka aku sudah alam tetiba muncul grub bani abd had mbah dan ketika aku mek kenal beberapa orang saja
# abam pres badar nuqaba pling boekkk dia hebat dlm bidang agama tkut tgur member sndiri selalu wat lawak hambar pling aku ingt smpai skrg lawak dia klau org ckp jom gerak skrg dia akn gerakkn badan dia chubby
# orang anak pekan telah ilham dasar ekonomi baru deb dan jadi gerak utama kepada maju ekonomi luar bandar beliau adalah allahyarham tun abdul razak malaysiamemilih hogohundi
# hahaha sialaaan nih nyata klo laper presiden juga mau sikat sama doi
# mau nasehat kali supaya ugal nih rezim tapi ini negeri sdh keburu ancor nah skrg saja ekonomi morat marit kacaoooooo
# aelaah silit kebeler ngapa dikasianin org makin sayang saya pak telah kasus sosmed baru sadar bbrapa hal seitansai kemarin tar ceritain duuuhhh
# iya tdi cacad
# tahun rakyat makan aspal dan beton ini adalah solusi jitu kurang miskin ahli cebong hanya tukang tipu cebong mah gitu goblok nggak ketulungan plonga plongo akibat optimisme lebih gantipresiden
# aku pernah sempat baca ttg harun yahya ini belot kubu yahudi dgn freemasonry nya kdg suka percaya
# kita maju sama ulama kita gerak sama semua tokoh agama untuk indonesia nderekgusmus
#
# mukidikepedean peanyaan mudah jawab keras tapi saya minta jawab keras siapa nama saya
# kemarin hujat sekarang harap dasar para bani kamprey
# jelas bukan fitnah silah ban apollinaris darmawan sebut quran kitab sampah
# monyet aja koloe dbilang saudra sma elo pasti ogah hdupmu kok gin amat toe hati apa comberan
# body lufra scrub bhn dasar lidah buaya utk mlembabkn kulit amp lbh bcahaya info bmi
# tak punya cacat masa lalu krn blum masa lalu
# jangan anut bumi datar juga soal teori bumi bulat kan dari orang asing notabane musuh mereka
# becak warga binjai hendak sita karena guna tenda beuliskan gantipresiden pks radang bukti perintah panik dan takut
# lebih baik jokowi mundur
# munas alim ulama ppp semarang hasil lima rekomendasi syarat dan kriteria kriteria bagi calon wakil presiden yang akan damping bpk jokowi datang romahurmuziy
# luar biasa cerah nya saya rasa gagal bagai anak ekonomi wkwk
# kafan asal dari budaya yahudi kenapa umat islam klaim
# oleh rezim skrg atas kendali negara cina komunis mjd patron tunggal rezim anti islam jokowi
# itu tanda nya mau pilkada pilpres
# misi bangun masyarakat yang gotong royong toleran dan harmoni selaras nilai budaya jawa barat yang luhur jabarasyik asyikm nang
# tabah pasang taufiq dan puan nurliyana yang wajar contoh jom kita beri sumbang untuk ringan beban pasang ini come twitter your things bsn bank islam nurliyana bte abdul raziff
# apaansi tai baru doang belagunya udah langit inget ada karma ntar bbrp taun lagi kalo idol flop gua ketawa paling keras
# celeng kgn
# teranginegeri dengan budaya yuk pada visit purwokeo mumpung ada even rakyat purwokeo extravaganzabanyumas
# presiden itu punya dana taktis dia bisa guna untuk penting rakyat luar program perintah yang sudah ada soal program banyak sekali ada bangun infrastruktur kip kis seifikat tanah hutan sosial bbm harga padat karya
# aamiin allah tim kan aja sampai latih ular karena dia dapat rawa rawa aku dapat sungai gede dan musuh buaya wkwkw
# maju kamu ngatain mama aku bolot
# grombolan kadal jidat gosong mmg bgtu suka ribut tapi klo grombolanya salah pura budek dasar grombolan cingkrang url
# segitu gentar dia takut hadap kafir
# betul padahal saracen juga siapa sehingga akun yang kritis anggap saracen kan aneh jokowi
# siapa bego bukan tmn gua najis dah kesel sendiri gue
# kafir kristen selalu buat ulah
# tau dong bau bau udh cir ini sipit buluq
# kayak pegang bukan mucikari
# guru dharma wanita satu desa plumbon porong deklarasi anti hoax ujar benci issu sarah dan dukung pilkada damai
# anjir rem maennya begitu
# kayak bisa atau cuma bank teentu bilang aja mau jual uang asing tukar rupiah
# onta yaman tahun lagi gua depoasi loe
# hati hati berita pilkada yang bau hoax madiun madiuntoday thmadiun kotakarismatikmadiun tolakcukaiilegal kunjung juga
# anak cocot ini
# udah tau hoax fahri mangkanye klu ambil berite tuyg update jangan dari tong sampah ambil terus tau rit udah
# mantaaap dekat sama banser bang
# nyata ada lebah gak suka bunga tapi makan bangkai penasaran madu nya kaya gimana
# pantas indonesia mundur dalam segala bentuk
# naahh dongo bilang hekell hahaha
# hahahaha blunder cebong gak ngasih tuh pem pusat dengan alas ham kalau rakyat aceh mau kali pun cobak kau datang perintah bilang suruh buat hukum islam kaffah aceh klau dpr
# bangsad gua dah nyelem ampe bawah balik lgi atas
# saya tak bisa pancing pancing dgn urus nista atau bukan saya hanya bicara paham saya ttg fiksi dan kitab suci
# cebong kacung itu temen dungu sampe tulang sum jgn buang energi debat mereka
# paai korupsi sapi goblog
# signal kntl pelihara apalagi ini niat gak sih login twitter doank susah amat gmn mau open redtube cetan
# matane aku moh aku kafir wkwkwk
# jadi inget fesbuk anjir lupa aku
# kalo aing sih bakal bilang hilih kntl
# nikita mirzani udah pake hijab masih ngomong cebang cebong udah pernah fantasiin doi bom cokorers
# tatap alih arah lain enggan tatap pria curiga itu lagipula siapa yang peama kali buat gaduh suasana jika angie tidak temu ada orang pria asing yang tidur sofa jadi pei ini tidak akan jadi
# lahir dan kembang gera komunis indonesia tidak dapat pisah dari buah organisasi nama isdv
# shaheizy sam wajah baharu calpis
# serah aja balas kembali fokus kepada kerja kita kami kerja tugas project seni budaya hanya dalam hari telah langsung kumpul dan presentasi syukur nilai muas telah jadi project itu kami makin
# bakal bro
# laku bodoh masuk kategori buat tidak senang laku sontoloyo sangat menganggu satu bangsa laku naif cara tidak langsung sbg bentuk intimidasi thd ulama laku
# monyet turun mukim warga cibadak sukabumi url
# kotor masalah yang penting bahagia warga cebong mana ngei
# mau giveaway taplak meja tapi nanti yang menang cuma therichchenle
# sudah buka satu demi satu kebusukab kubu anies sandi menang dengan tanpa berkah url dan prabowo usaha cuci tangan
# wkwkwkwk bodo bang
# bik kaya orang bego bro tapi memang ego
# klhk upaya perata ekonomi lalu tora kawasan hutan dan hutan sosial tribun medan
# pak mahfud sudah paling dari allah swt berang demi bangsa ajak semua buang islam
# orang bego banyak minum amp makan kotor onta otak nya somplak
# apa yang kuak semua sudah jelas sejak awal memang itu strategi kampanye kami tim menang anies sandi url
# warga baduy telah selesai ingat tradisi seba pendopo pemkab lebak akan lanjut kembali beemu dengan gubernur banten wahidin halim hari ini sabtu sebabaduy
# lembaga anti korupsi masa lalu bubar krn sentuh kuasa gilir kpk kenapa pdip paai politik kuasa plg ngotot ingin bubar kpk
# justru mas klo mnyudutkan salah satu agama tentu malah bahaya itu pak rocky ini cerdik dia bisa nyusun kalimat tepat amp pantas dgunakan inti dari ini dia mau kasih tau pngeian fiksi sbenarnya ayo mas nya
# para dukung capres gagal move salalu sibuk urus aseng bawa kabur uang tapi ngak sadar kenapa aseng bisa kabur bawa uang banyak itu tanpa dukung pribumi asu mustahil aseng bisa pribumi hanya diam kalau sogok mental kacung emang url
# rabun apa budek gue nulis gak ngomong
# bismillah nahan sepo yang kutuk
# brahahahaaa cebong nya ngahok cebong blm cebok
# apdet status bikin tugas kelar gak kok jancuk sekali mbut
# pak walaupun anda muslim bagai jabat negara anda harus beindak demi bangsa negara
# ikan sudah sembuh dari sakit dan masih selamat bagus laik jual harus pisah atau seleksi dari ikan cacat permanen untuk pelihara lebih lanjut kesehatanikan
# ainya apa pribumi sadar lihat siapa mereka kecuali kalian sama sama cina komunis misionaris abai tweet ini usir cina indonesia
# presiden yang anda tuduh rezim anti islam sudah banyak buat untuk negeri ini sudah bnyak buat untuk umat url
# manusia bangsad
# tpi ingat jangan sampe cina kenal wisata haram jga indonesia hahaha
# nanya mana prabowo dan pks saja bib kan asoy tuh anggap antek prabowo dan antek pks hidup pasti lebih dramatis
# sahabat salah lovren ini jadi bukti bahwa beda suku agama ras bukan halang dlm bina hubung dgn sama umat manusia beda justru jadi warna sendiri dlm jalin peemanan terima kasih lovren salah favourites bff bro
# sama aja lae meski sdh turun turun ideologi pki sllu lekat jiwa mreka
# saya juga sebel kalo ada ngeroko sambil naik motor yakan kadang engap kalo tutup terus apalagi macet
# udah minta maaf kunyuk bro enak bgt rasan mereka sebar hoax minta maaf sebar hoax lagi minta maaf lagi mesti sapu dulu biar jera nih orang url
# hello warga jakaa wakil kepala dpmptsp provinsi dki jakaa bapak denny wahyu haryanto wakil wakil gubernur provinsi dki jakaa buka acara junior chamber international jci indonesia national event setiamelayanijakaa
# selain kuat jaring gubernur juga tekan perlu kuasa state the a knowledge sea bahasa lama rantau luar indonesia
# pandang tgb hadap agama dan politik
# provider brengsek
# susilo bambang yudhoyono presiden minta khofifah emil untuk dekat dengan masyarakat bisa baguss
# yang dungu itu orang yang mau ganti presiden tau siapa mikiiiir
# bokep cewek bispak bandung ngentot croot dalam download full url url
# kampret complain rag ditanggepi fuck
# kamu kok kaya jablay gta mau jemput pake mobil
# lihat memek tante
# sementara itu kerja musuh dakwah islam bubar hti rakyat hak lengser jokowok tukang citra
# hah kata saling lengkap orang bukti kamu juga goblok gimana
# ctidak kata salah orang khalifah rasyidin itu ckami dahulu rang orang kafir sama mereka ckalau begitu mereka orang orang munafik ctidak juga sebab orang muna
# dia doyan nete jadi maklumin
# nek ndelok match terkhir celsi sih kudune menang mudah emyu tapi embuh sih celsi kacrut raiso prediksi
# yakali pak tni suruh urusin sampah plastik
# itu khawatir dari manuver politik dan bijak laku oleh rezim ini moga hal sebut tidak akan pernah jadi nkri cinta aamiin
# madi arya lapor rocky gerung polisi serius tuh kitab suci itu fiksi kata rocky nyata itu salah anda rasa hina wait bukankah biasa anut agama anggap kitab suci
# bajing tengik memang
# kok pake buruh cina kan rakyat sendiri bnyak pngangguran dasar rejim kodok
#
# haneul pada cute padahal rlnya perek yang retweet
# bilang anti asing aseng nda tau wkwkwkwkwk
# suriah sekolah radikal dan rakit bom plg indonesia jadi tempat pkl aman
# karena kadang hidup emang kayak tai malah kadang yang berak orang lain tapi elo yang harus resin tainya tangan
# banci selotipan
# haha kalah yee org jahat pasti kalah
# gubernurzamannow gusipulputi ganjaryasin djarotsihar hasananton kosterace nurdinsudirman karolingidot keanekaragaman budaya suku agama itu sungguh kaya kita tutur djarot hadap pesea rakercabsu
# cinta orba pasti meng idola kan prabowo amp hary tanoe
# nantang buka dada nyebut setan emang sudah pada habis kamus ngelawan kenegarawanan pak joko widodo presiden pada makin stresssssss nie hati kena stoke atau serang jantung nanti rakyat indonesia hilang badut politik merdeka
# belah duren yaaaa gak dungu gak cebong maaf
# orang orang yahudi dan nasrani yang telah kami beri kitab taurat dan injil kenal muhammad
# bubar hti amp fpi url
# ahok memang verbal keras lampias dan lari karena lelaki lunak
# dar share juga temen kantor aku kalo ada langgan cadar langsung bilang awas ada bom aku hanya hela nafas xaf
# pantat pngen nusuk dan tusuk open gaybrondong massageboy gayjakaa gayjogja gaytangger
# ancam untuk bunuh itu presiden republik indonesia mas trus mesti lapor dulu apakah tegak hukum gak bisa beindak jika ada ancam bunuh kepada kepala negara
# kayak orang nyosor mau minta nete
# ngewe bae
# jebur bloon bukan cebur
# pks ultah balai kota ngomong nyapres balai kota ganti aja nama balai politik
# pak perlu lanjut rencana untuk seret adil ham pbb url
# bijak kembali barang kpd konsumen laku apabila barang sebut rusak cacat produksi atau konsumen rasa kurang puas dgn produk sebut hitung lama hari dari tanggal beli hauzminiquiz hauzid yuk ikut
# kisah hidup muhammad yang lebih lengkap dapat didownload sini
# jajah atas bumi indonesia harus hapus kan jajah ekonomi budaya hasil bumi oleh cina harus kita basmi demi nkri usir
# ada pipis onta cecer mari pantes bau pesing
# kalo jadi sini mungkin juga kalian triak paling lantang pmh pro aseng duluan pas tawar bantu asing bikin posko ini itu inti malah ngomporin keluarga korban sue pmh bilang hari lama harus
# mari juang sampai jokowi dilanti kembali thn jangan gentar jangan takut walau mata benang leher walau ujung tombak porut tidak akan surut langkah kita tidak akan bisu suara kita tidak akan
# kaya monyet
# survei metro jokowi menang dari presiden baru etapi cara ngitungnya gimana bisa ngalahin jangan salah judul maksud jokowi masih menang sumber zie bajrie
#
# cuba tgk anime karakai jozu takagi san kalau rasa nak feeling feeling cinta monyet zaman sekolah memang throwback habes url
# seru pesta budaya erau kuta kaanegara
# yang mau contactnya retweet sekarang banyak banget kenal tante jilboob sange ini nama tante dea
# debat publik bukan ajang bukti siapa pintar atau balik juga bukan ruang akademik untuk pamer siapa paling ciamik tiap orang punya kuat dan lemah bukan hanya soal diri itu egosentris nama ini lebih pada soal kuat tahan
# duduk istana negara sekali lengser jokowi salam tahun
# wah hebat pak sibuk citra baca nih
# bagi anda mungkin apa tapi bagi kami muslim ini sangat hina kami iblis betina itu sdh nista syariat kami
# baby kafir budha teroris myanmar
# indonesia blom merdeka indonesia masih jajah oleh orang cina takbirallauakbar url
# memang benar kata amat politik hantayudha kalau paslon ini tidak ada khanz nya jateng jatenggayeng tetapjokowi
# jongos nista agama ahok sok sok ngong sara majikan nya tebar sara astagfirllah tobat
# boleh saya follow bli juga saya katolik dan ikut akun prof utk tambah wawas bangsa terima kasih
# kapan tuh bejat cabul balik kecut onta itu
# turut wibisono citra jokowi telah sebar media massa pro asing sehingga kes jokowi hasil
# adi gaya kaya beruk gin klo supir tembak metromini masuk dpr kampung
# terlalu mainstream mengaaikan pintar pintar itu relatif gantung bawa mana pengeiannya spt anda pintar meng undeeestimate kan org pinter komen ajah rejim now pinter mangkrakin janji doang making
# kan emang dongo
# masak samain smaa sampah
# terpukaukaukau gantipresiden
# aspirasi ibu lina dari sumedang kepada calon gubernur jabar berantas pelakor yang sdh resah hidup warga desa
# yaaelah chat aja loe urusin noh dah liat mesum anggotadpr mingkem nyata selingkuh kalian pura budek bong nyampe otak
# yang saya kata sejak dulu lagi kita tak takut dgn cina atau pai dap tapi kita bimbang fahaman yang bawa oleh mereka
# cermin pun pecah saat diri kaca
# lansung tag paainya berani berai kau banci
# awwww comel nya asing kan ikut warna
# islam jadi manusia yang idealis namun tetap realistis siap hidup masa kini namun tak lupa masa depan ajak kerja keras dan ajak pula istirahat
# kristus anjing asu jiamput keparat picek telek pejuh siwuk kotang siwuk idiot keparat picek telek pejuh siwuk kotang siwuk idiot keparat picek telek pejuh siwuk kotang siwuk idiot keparat picek telek pejuh siwuk kotang siwuk idiot keparat picek telek pejuh siwuk
# agama katholik ngak ada sebut khatolik nusantara agama kristen protestan ngak ada sebut kristen protestan nusantara agama hindu ngak ada sebut hindu nusantara agama budha ngak ada sebut budha nusantara lha kok ini
# karena bas teknologi digital presiden juga minta sistem betul betul jalan dan langsung bisa guna dan ramah bagi guna ratas
# ahhh itu kan asa saja utk hibur diri mana ada cebong tdk bahagia presiden cebong punya tol cebong punya lha elo punya cuma germo
# kami lebih resah anda presiden hidup anda penuh drama dan citra main ftv aja joko judul url
# agama kristen golong darah asal san fernando valley
# budha bunuh muslim myanmar
# jahudi bangke minta sama jerman sana tempat ibadah
# papamintaketuafraksi rakyat mau nya setya novanto keluar dari dpr bukan pecat dari ketua dpr percuma saya pecat dan masih ada dpr
# cina
# hoax kodok biawak roket sekop bangsat karbitan munafik gantipresiden presidenbaru tenggelamkanjokowikesungaisiak
# itu pada ribut komunis blabla mungkin emoh baca baca pun kalo punya niat agitasi nyerang perintah pake ini cari simpatisan
# presiden jokowi harap skema kerja sama ini juga dapat laku dalam bangun bangun lain
# milu langsung biar bwt milih presiden dpr capres pun biar tdk kyk kucing dlm karung mgkn bisa bikin mekanisme baru lebih misal capres tentu dari gubernur prestasi boleh maju capres hanya sdh gubernur
# gak vital gimana udah dari kapan inter gak punya bek kanan bisa beda akhir itu era maicon ambrosio juga baru telah datang cancelo bagus hmmmm berai simpul geblek ausilio ini
# nama agama munafik
# contoh lain meski banyak tuding duga korupsi tapi sby tdk pernah dorong jaksa usut apalagi himbau kpk usut duga korupsi jokowi
# saya cium bau bau pecun url
# henti jadi konsumen wisata haji umoh tipu jadi podusen wisata jiarah indonesia
# buru nazi simon wiesenthal pegang foto foto yang gambar mantan kepala gestapo walter rauff dan buah van kamar gas gerak yang buat untuk eksekusi orang orang yahudi
# ada cacimaki nista agama tapi nyata tau poligami ngumpet apa mau digituin saya sih ogah
# bubarin nkri harga mati
# ingat baik baik kata royson jokowi kacung gua itu mungkin alas fundamental kenapa rezim ini justru pei sengaja masuk dalam debt trap komunis cina jadi wajib untuk gantipresiden
# wkwkwkwk mampus aku mau pepet ujin
# gubernur jaman now anti hoax bukan nyebar isu yang tidak pasti ganjaryasinmenang ganjaryasin kamiganjaryasin
# azan manggil allah swt dungu biadab harus henti dan acara catut nama tuhan tidak boleh lanjut
# semua itu dapat pada laku bani cebong
# aku dah baju macam yahudi betopi siap bas geng semua jubah putih kopiah minyak atar bejanggut dahi bekuk bak ahli syurga siap betol out place mohon tak direjam
# gua akan marah cuma auto blacklist dari hidup gue sampah apa guna kalo daur ulang
# anjir apa rasanyaa bekas silit mah
# cebong makin panas jadi makin ngawur
# amin smoga kalian beiga bisa tampil yang baik dan sumbang medali buat sumsel
#
# gubernurzamannow gusipulputi ganjaryasin djarotsihar hasananton kosterace nurdinsudirman karolingidot keanekaragaman budaya suku agama itu sungguh kaya kita tutur djarot hadap pesea rakercabsu
# sudah jangan terlalu banyak bingkai bangkai cukup jadi ajar saja agar hidup kita makin baik pada masa yang akan datang
# edan yang mas newbie menang saja liat yampun kau aja mas dikit bat
# nah klo pki alias paai korupsi indonesia perlu ganyang juga
# perempuan kaya mending mati aja deh jelek aja gausa sok jadi make aist
# jual lagi gua kaya jablay
# yang bijak cuma tugas dan jajar krl doang para tumpang cuma followers doang xef nyuruh orng utk mengei sendiri mau mengei butuh banyak orng kan bangke
# kyknya itu titit nya sambung trus pake accessoris
# mata pas kecil sipit skrg malah engga aneh pis
# ingt aku buat banci gigih kira url
# waspada cina komunis yang ada indonesia
# banci kampung heeee
# gembel ganteng perlu kasihan karena byk cinta asik asik jos
# dekalarasi pilkada aman dan anti hoax toga jemirahan jabon
# setiausaha agung pas datuk takiyuddin hassan sahkan ada pihak cuba pinda lembaga pai ini pei yang kata presiden pai belum ini
# emang aku najis
# sastra karl mark pentol komunis rusia
# otak mereka kayak bener bener bool deh mess trus tiap harinua makan silit jadi gtu
# ganti rezim kacung lah cebong mah gitu kalo tanya
# cina apa hak larang
# anda hebat bicara cinta masih pegang quran sbagai pegang hidup quran tak bicara cinta tapi perang bunuh penggal
# lama jomblo nanti jablay
# perjaka jual sok sok mau booking tante idiot njir
# rev jgn pilih ulama dekat kafir dan munafik
# buat ngejaga bersih lingkung tuh orang belum pada melek sama wajib asal buang sampah dan ngomong kan ada tugas bersih
# sejuk gila dlm ofis kulit buaya apa
# ooo camtu biasa kena imbang ada baik ada nakal ada kucing ada anjing ada abang ada lain lain ada darkside ada brightside tak chill dan tak sosial kalai takde lengkap kahkahkah bang selamat maju jaya dah jawab soal saya terima kasih
# segala masalah saat ini hanya ada satu solusi gantipresiden jika pun tdk dampak signifikan kurang nya kita telah obat dan cegah sakit ini beambah parah
# gampang kak buka buka browser ketik budaya palembang silah nikmat ajar denngan gratis
# gerombol onta ngaku bela umat tapi itu semata demi kepentinga politik praktis tgb jauh lebih demokratis dia penting umat pikir modern salut untuk tgb
# culun mending kampung jes
# goyang jilboob mantap bener nih hyper kontol doi tadi sambil squi loh yang belum nonton live nya besok doi
# islam indonesia itu adalah islam nusantara islam yang sudah modifikasi demikian rupa supaya masuk dengan budaya indonesia yang agam islam nusantara adalah islam yang toleran
# presiden aspek indonesia mbak kami tidak anti investasi asing tapi apabila ubah jadi invasi asing sudah wajib kita bagai warga negara utk lawan
# pkl wib kanit binmas ipda hutasoit melaks sambang dan sampai pesan kamtibmas ttg pilgub dan pilkada kpd karyawan bri ranting muara damenra sihite dkk desa hutanagodang kec muara kab tap utara
# kalimantan sdh biasa matlam gin batu bara nya keruk listrik megap
# fardu kifayah atau hukum wajib dalam ajar islam pada pilpres datang harus ada utus dari kalang santri yang sokong ulama untuk maju pimpin negeri
# hah wah bangke emang nih truk
# nahdliyin minta setop hina hadap maruf amin
# cebong kampret dan onta juga ngak singgung dengan laut
# risa baru saja pulang dari latih khusus ketika iris hazel milik tangkap siluet orang gadis gadis yang sangat asing belum pernah risa temu gadis ini belum radio tempat tinggal dan kerja ini maka dari itu
# hahahaha orang gila ngomong cak makanya jangan terlalu banyak micin biar otak loe encer cong ngomong ngawur muslim kamu itu muslim silit tau babi
# coba ngaca introspeksi apakah keluarga anda gak pake hijab komunis jga otak pakai jgn cmn propey
# muhammadiyahinggris jalin kerjasama kendali ekstrimisme
# kalo neraka kena bom maka surga akan selalu ada untuk semua org muka bumi ini masuk goku
# bot mau nanya ich liebe dich ainya apa jawab ntar bot kasih aipet barusan nyemplung jamban kuda xcc xaf xcd xcc xaf xcd
# copot darmin nasution menko ekonomi bodoh yang turun daya beli sejak jabat
# bodo amat anjir bodo ngakak gua ngakak astagfirullah humor bet url
# mata picek cukk ora dok prestasli pak jokowi guoblokkk tolol
# hasil penjara ahok alumni dukung rizieq akan lengser jokowi usai lebaran
# coba dedengkot jin terus terang para ulama saudi atau rilis publik tentang akidah jin contoh jin tidak anggap kafir peluk kristen hindu budha dll semua punya peluang masuk surga aku yakin akan keluar fatwa dari saudi jin adal
# atau pei hujan lebat dari langit sama dengan gelap gelita dan guruh sea kilat mereka sumbat jari dalam telinga masing masing dari dengar suara petir rana mereka takut mati masakan mereka boleh lepas sedang allah
# cerdas dan konseptual
# nama baek yoon ucap putus iring dia kerjap mata yang asa antuk sedikit demi sedikit gigit bibir ragu karena dia ingin gapai gelas sekali lagi untuk minum bagaimana wine yang tinggal
# bismillah melayu raya tanah melayu macam macam nama kita pernah dengar tapi pernah tak kita kaji besar mana jajah tanah melayu dulu dalam thread ini saya akan kupas serba sedikit tentang bani jawi
# bila nak kawin kena simpan duit ilmu agama kena cukup semua benda kena cukup senang cerita
# aduh lucu banget adek kelas gue pas sma lapor kata bang hari ini kita field trip taman safari heran dah nyebut nama temennya dia mau arisan ama keluarga aja bawa sekolah tai arisan
# gimana main asw
# ini hebat dan arif suku baduy hutan tetap jaga budaya jadi nafas hidup mereka hidup dgn jaga imbang alam
# yailaah gilir gin aja pada rame ngebela dulu pas idol mati cuma sedih doang malah serbu gila yang sarap siapa maap
# sabar doa usaha ikhtiar mudah mudah bentar lagi gantipresiden gak pake contek gak pake planga plongo
# umat islam siapa ente mksd fpi hti mrk bkn muslim nista islam bajing mrk itu muslim tdk mgkn buat onar kecut lari tgg jwb stlh mesum apa islam apa islam gilir mesum apa itu islam buat onar itu islam
# warga semarang prihatin kontroversi puisi gus mus
# celeng nya bang acon susah bgt dah
# tapi kenapa kamu malah cari musuh dasar ana cebong kampret
# tuju dpr menteri dan seluruh jabat negara wajib potong masuk presiden tiap pns potong pegawai swasta tidak potong
# cie akun hasil bodoh kaum bikin kaum kaum sendiri biar kata jokowi anti islam wkwkwk
# yang juara ngibul kan junjung kalian wahai bani kampret
# aku ada turun cina tapi aku sipit
# tanya amin rais dulu dia bikin kacau dan nyuruh reformasi pilkada salah satu hasil
# fahri hamzah kalau saya jadi presiden kpk akan saya bubar url
# dia takut banci tapi url
# linmas wilayah tawangsari bulu amp weru terima bekal pam pilkada serentak
# kenapa bolot
# doi tuh native speaker mother language nya english komen jaga dong bangsad
# kita kita biasa aja dengan nyata yang ada ngerasa bangke
# mungkin mrk slh tulis atau slh sebut aja mkst nya mungkin cebong muda kampung
# uname absurd bahkan first impression gak akan bikin enak imaginenya dan gak ganteng typing pas coba eue enak banget harap lagi nyata enggak sama sekali
# admin bukan presiden tapi
# stw singaraja suka kontol url
# kafir haram jadi pimpin nyet
# shio baekhyun itu monyet
# ceruk pasar itu pasar lbh kecil satu pasar itu pst butuh kita cth asuransi pensiun tentara tuh semua org pensiun tentara sekali pensiun tentara pst asuransi tsb atau alat butuh org cacat semua org cacat
# emang perlu pak kyai staquf nyebut suku ras biar mudah paham nalar ente bahlul ane tanya ente soal arab mana ente sembah aja bisa jawab ane sodorin arab bani saud pro israel ente pura
# pernah ngelakuin dosa apa anis dan sandi sampe bully dan rendah terus padahal masih bnyk orng jahat dan licik sebenarny lebih pantas bully dan rendah dunia memang kejam kawan
# kalo memang ajar agama budha atau hindu bener harus bgini coba ajar bener belum buka mulut
# ikut alam tak berapa kerja pa time dengan cina lebih best dari kerja dengan melayu haha
# aku gakuat karna jijik makanya cepetin asa kita kejar yaaa sampe mau napas aja jadi sungkan wkwkwk
# bubar dpr bubar savekpk
# hehehe akhir nyata pasar kita global tdk batas lokal akhir mas ada aseng dan asing juga kita jujur saja
# gua daiping mampus junedi
# suciwati revolusi mental jokowi omong kosong bual jika tuju amp comment url
# saya juga pernah marahin orang yang panggil saya sipit waktu jadi hoshi atau yang suka tanya mata mana sepele tidak itu kan bagi dari fisik mungkin kalau pakai untuk definisi macam hoshi itu yang milik mata sipit boleh deh
# jangan jangan otak makelar jual asset negara apa maling asset negara peamina jual mau isi tka dari tiongkok gantipresiden url
# akun siti fatimah amp komen laman diringkes semua aja parah amp bejat malu moga sehat selalu tetap sabar amp semangat terus suara benar
# bawang putih itu sdg kafir haram lagi hiks hiks hiks
# tuju ahokers lengser prabon jokowi daripada ancurin penjara karuan url
# rawan join adalah buah gera arus bawah rindu pimpin nasional dari nasionalis islam moderat cakiminthenextwapres join
# onta nsd
# umpan pake apa biar mancing dpt buaya
# komunis kok berabtad pki kecoak makan kecoak dong
# retweeted ikko pribumi kawe horas horas horas dengan guna kapal feri presiden unjung pulau samosir dlm rangkai kunjung kerja presiden sambut dgn upacara adat samosir pekik horas horas horas
# mata loee picek janji jokowi kok tagih sby mata picek blok
# yang dua indonesia akan beahan bahkan bisa jadi kuat ekonomi politik baru jika hun pilih bekerjasama dengan simpan beda tidak penting macam agama
# sudah lebih dari tahun freepo kuasa oleh pihak asing baru masa perintah jokowi sea pak jonan jadi tri esdm freepo kita ambil alih saham jonanjos
# clara anak pinter dongo paling koplak cantik tapi idot gatau malu urat malu putus butt dia muka nya imut bgt
# menag minta riset ptkin jgn hanya orientasi publikasi aikel scopus dan jenis namun outputnya hrs bisa jawab tantang umat islam ptkin perlu buat pangkal data sbg rujuk bangun misal database ulama nusantara shg
# presiden paling buruk dalam sejarah bangsa cebong
# nusantara kan dlm ai nasionalisasi assets asai asing hny bisa laku pimpin sungguh nasionalis patriot nusantara versi proxy hny beujuan lemah tahan nusantara nasional suatu bangsa
# foto profile nya saat naik pesawat msh blg jgn cinta produk asing dari hal sederhana ini saja kita sdh ukur berapa parah tingkat munafik lbh baik anda lgs terjun dari pesawat biar ucap anda sesuai dgn buat
# remuk rengginang cocot
# dah padah even kau bodo bulak curang pun dgn ompu nya still maok kau segal sayang kau bodo sikpande hrgai
#
# acara mutu ini ulah mntan aktif gmni ormas mahasiswa gembong pki musuh bebuyutan hmi
# ayo pilih alin aja alin tuh bawel banget semua diomongin ngeliat banci jalan aja aku omongin tapi baik kok
# sudah adopsi perintah pusat juga nich
# pak prof jangan pak prof bilang itu cuma soal dapat itu tdk benar karena sampai forum buka itu ngaco dan tdk bisa biar pak prof bagai muka agama dan bagai ulama harus melur
# biadab tuh oknum aparat keparat
# hahahaha jancuk
# untung aku kunti
# kaisoo itu couple yang hangat waktu bandara tanggal maret kemarin mereka nggak mau kalah sama hunhan dari korea sampai cina dan dari cina korea kai demen banget deket deket kaisoofact
# wuakkakaa mampuss salah gue diblock dia sejak jaman jokowi ahok nyagub gaya toong toong anies sandi url
# dan dari orang asing yang ngobrol karena bosen nunggu transit akhir jadi temenan sampe sekarang
# itu dia mata picek mata cuma lihat belah
# maaf benar twiter peama kali dbuat bukan buat orang bego
# kocak kalabong emang dungu
# sehingga catat itu yang kami buka kembali tidak boleh lupa alam pilkada dki jakaa dan yang usung paai gerindra dan hasil tumbang tahana yang usung oleh koalisi besar yang motor
# kenal walpri perempuan dalam pilkada bondowoso radar jember
# sana mayoritas budha ada pendeta ikut demo kau googling lah video demo thailand biar tau
# begitu cara komunis main
# suka kesel sama orang yang pas gua jadi confess gua gilir gua jomlo malah pada mana tau ngomong sama silit
# ehhhhh bandot mau kritik pak jokowi ampe mencret darah tpi klo hina fitnah kami akan ambil tindak pak jokowi presiden pimpin negara pimpin agama tpi salah kaprah luuuu
# kita balas sini gima kita usir budha kurang ajar etnis muslim rohingya singkir dari data sensus duduk myanmar
# astagfirullah mata noda kutuk kau nge bokep xad
# allah tidak panggil orang yang mamputetapi allah akan mampu siapa saja yang mauyang rinduyang yakin baitullah
# kntl apus
# obat monyet kedih url
# pergi bangkai
# bingung akan apa yang bisa toleransi dan enggak bikin mikir itu alas kenapa dalam katolik ada paus bagai wakil kristus
# itu udah ketawa kunti
# aamiin rabb tolong indonesia alah dgn lebiiihhhh baik
# ustadz pks yudi widiana nilep duit bahasa agama juz amp liqo felix kwetiauw amp alumni mingkem amp pura budek gilir
# amin smoga istiqomah jgn khawatir cibir org anggap aja uji ingat banyak org dulunya masalah suram bahkan kafir sekalipun kemudian taubat dan jadi tokoh juang agama islam
# video call dengan pak gubernur yang sedang dinas istanbul turkey dalam video call ini saya lapor yang peama ialah tempat hibur malam karaoke sense amp diskotik exotic telah tutup cara hormat tanpa harus keras bantu ole
# yang kita bela adl pancasila dan daulat negara kalau tidak dukung maka lengser saja saat ini ancam sudah nyata
# proyek saracen utk ganjal lantik anies msh teruus temu baru kasus saracen ada foto tokoh paai politik
# itu ahok kutil babi
# kenapa sukarno tidak konotasi juga rejim anti demokrasi embel presiden umur hidup
# hajar ndan ganyang pki url
# bangke sampe bsa tidur siang
# pak jokowi kasi goregan pbb
# amiinnnn dan moga pak jokowi jadi presiden lagi
# daripada gak meni sama sekali daripada simpang lgbt nikah hidup lebih berkah dunia sdh rusak dgn perzinahan kini ada gera stop kawin dini
# kapolri harus mundur dari jabat
# daya ekonomi pesantren ulama jawa barat dukung jokowi pilpres tetapjokowi
# semangat terus pak kantor staf presiden harus depan publikasi semua giat presiden supaya rakyat tau bahwa presiden kerja keras bangun bangsa ini kerja kerja kerja
# daripada cocot
# ini saya tuju makanya dukung presiden yang sudah upaya kurang kuasa asing kurang ekspor mentah ganti kontrak yang rugi indonesia
# kristen nusantara pasti ada conth hkbp huria krsten batak protestan gkj greja kristen jawa gereja pasundan gereja manado gereja malu gereja papua dll masing punya ciri khas sesuai tradisi suku masing
# baru tahun dah segitu bentar lagi lewat utang sby njiiieng
# mungkin masih banyak masyarakat tionghoa lebih pancasialis pada wong jowo nggak terekpos aja contoh nyata pak kwik ekonom dan ustadz felix siauw

# %% [markdown]
# <hr>
#
# ### Split Dataset
# In this work, I decided to split the data into 80% of Training and 20% of Testing set using <b>train_test_split</b> method from Scikit-Learn. By using this method, it automatically shuffles the dataset. We need to shuffle the data because in the original dataset, the tweets and sentiments are in order, where they list positive tweets first and then negative tweets. By shuffling the data, it will be distributed equally in the model, so it will be more accurate for predictions.

# %%
x_train, x_test, y_train, y_test = train_test_split(x_data, y_data, test_size = 0.2)

print('Train Set')
print(x_train, '\n')
print(x_test, '\n')
print('Test Set')
print(y_train, '\n')
print(y_test)

# %% [markdown]
# <hr>
# <i>Function for getting the maximum tweet length, by calculating the mean of all the tweets length (using <b>numpy.mean</b>)</i>

# %%
def get_max_length():
    tweet_length = []
    for tweet in x_train:
        tweet_length.append(len(tweet))

    return int(np.ceil(np.mean(tweet_length)))

print(get_max_length())
# Out:
# 75

# %% [markdown]
# <hr>
#
# ### Tokenize and Pad/Truncate Tweets
# A Neural Network only accepts numeric data, so we need to encode the tweets. I use <b>tensorflow.keras.preprocessing.text.Tokenizer</b> to encode the tweets into integers, where each unique word is automatically indexed (using <b>fit_on_texts</b> method) based on <b>x_train</b>. <br>
# <b>x_train</b> and <b>x_test</b> is converted into integers using <b>texts_to_sequences</b> method.
#
# Each tweets has a different length, so we need to add padding (by adding 0) or truncating the words to the same length (in this case, it is the mean of all tweets length) using <b>tensorflow.keras.preprocessing.sequence.pad_sequences</b>.
#
#
# <b>post</b>, pad or truncate the words in the back of a sentence<br>
# <b>pre</b>, pad or truncate the words in front of a sentence

# %%
# ENCODE TWEETS
token = Tokenizer(lower=False)    # no need lower, because already lowered the data in load_data()
token.fit_on_texts(x_train)
x_train = token.texts_to_sequences(x_train)
x_test = token.texts_to_sequences(x_test)

max_length = get_max_length()

x_train = pad_sequences(x_train, maxlen=max_length, padding='post', truncating='post')
x_test = pad_sequences(x_test, maxlen=max_length, padding='post', truncating='post')

total_words = len(token.word_index) + 1   # add 1 because of 0 padding

print('Encoded X Train\n', x_train, '\n')
print('Encoded X Test\n', x_test, '\n')
print('Maximum tweets length: ', max_length)
# Out:
# Encoded X Train
#  [[ 942 6445 3907 ... 2244    0    0]
#  [  24 1680 4906 ...  251  181 1042]
#  [ 274  162  165 ...   21   87    0]
#  ...
#  [ 302    0    0 ...    0    0    0]
#  [ 333  748 1985 ...    0    0    0]
#  [ 275  170  563 ... 3113  847 9234]]
#
# Encoded X Test
#  [[1593   11  980 ... 3663   75 3243]
#  [1142  204 7021 ...  703   21  703]
#  [ 511   21  262 ...   20  814 1674]
#  ...
#  [ 370    6 2725 ... 4991  794 5529]
#  [ 325   26  600 ... 4660  328  757]
#  [ 113 6536 4225 ... 1680   86  373]]
#
# Maximum tweets length:  12

# %% [markdown]
# <hr>
#
# ### Build Architecture/Model
# <b>Embedding Layer</b>: in simple terms, it creates word vectors of each word in the <i>word_index</i> and group words that are related or have similar meaning by analyzing other words around them.
#
# <b>LSTM Layer</b>: to make a decision to keep or throw away data by considering the current input, previous output, and previous memory. There are some important components in LSTM.
# <ul>
#     <li><b>Forget Gate</b>, decides information is to be kept or thrown away</li>
#     <li><b>Input Gate</b>, updates cell state by passing previous output and current input into sigmoid activation function</li>
#     <li><b>Cell State</b>, calculate new cell state, it is multiplied by forget vector (drop value if multiplied by a near 0), add it with the output from input gate to update the cell state value.</li>
#     <li><b>Ouput Gate</b>, decides the next hidden state and used for predictions</li>
# </ul>
#
# <b>Dense Layer</b>: compute the input with the weight matrix and bias (optional), and using an activation function. I use <b>Sigmoid</b> activation function for this work because the output is only 0 or 1.
#
# The optimizer is <b>Adam</b> and the loss function is <b>Binary Crossentropy</b> because again the output is only 0 and 1, which is a binary number.

# %%
# ARCHITECTURE
EMBED_DIM = 32
LSTM_OUT = 64

model = Sequential()
model.add(Embedding(total_words, EMBED_DIM, input_length = max_length))
model.add(LSTM(LSTM_OUT))
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 12, 32)            745920
#
#  lstm (LSTM)                 (None, 64)                24832
#
#  dense (Dense)               (None, 1)                 65
#
# =================================================================
# Total params: 770,817
# Trainable params: 770,817
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# <hr>
#
# ### Training
# For training, it is simple. We only need to fit our <b>x_train</b> (input) and <b>y_train</b> (output/label) data. For this training, I use a mini-batch learning method with a <b>batch_size</b> of <i>128</i> and <i>5</i> <b>epochs</b>.
#
# Also, I added a callback called **checkpoint** to save the model locally for every epoch if its accuracy improved from the previous epoch.

# %%
checkpoint = ModelCheckpoint(
    'models/LSTM.h5',
    monitor='accuracy',
    save_best_only=True,
    verbose=1
)

# %%
model.fit(x_train, y_train, batch_size = 128, epochs = 10, callbacks=[checkpoint])
# Out:
# Epoch 1/10
# 80/83 [===========================>..] - ETA: 0s - loss: 0.5800 - accuracy: 0.6682
# Epoch 00001: accuracy improved from -inf to 0.67252, saving model to models\LSTM.h5
# 83/83 [==============================] - 3s 19ms/step - loss: 0.5748 - accuracy: 0.6725
# Epoch 2/10
# 80/83 [===========================>..] - ETA: 0s - loss: 0.2753 - accuracy: 0.8887
# Epoch 00002: accuracy improved from 0.67252 to 0.88818, saving model to models\LSTM.h5
# 83/83 [==============================] - 1s 16ms/step - loss: 0.2758 - accuracy: 0.8882
# Epoch 3/10
# 83/83 [==============================] - ETA: 0s - loss: 0.1427 - accuracy: 0.9502
# Epoch 00003: accuracy improved from 0.88818 to 0.95017, saving model to models\LSTM.h5
# 83/83 [==============================] - 1s 17ms/step - loss: 0.1427 - accuracy: 0.9502
# Epoch 4/10
# 82/83 [============================>.] - ETA: 0s - loss: 0.0807 - accuracy: 0.9744
# Epoch 00004: accuracy improved from 0.95017 to 0.97447, saving model to models\LSTM.h5
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0805 - accuracy: 0.9745
# Epoch 5/10
# 81/83 [============================>.] - ETA: 0s - loss: 0.0546 - accuracy: 0.9825
# Epoch 00005: accuracy improved from 0.97447 to 0.98234, saving model to models\LSTM.h5
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0548 - accuracy: 0.9823
# Epoch 6/10
# 83/83 [==============================] - ETA: 0s - loss: 0.0393 - accuracy: 0.9881
# Epoch 00006: accuracy improved from 0.98234 to 0.98813, saving model to models\LSTM.h5
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0393 - accuracy: 0.9881
# Epoch 7/10
# 83/83 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9902
# Epoch 00007: accuracy improved from 0.98813 to 0.99022, saving model to models\LSTM.h5
# 83/83 [==============================] - 1s 17ms/step - loss: 0.0304 - accuracy: 0.9902
# Epoch 8/10
# 81/83 [============================>.] - ETA: 0s - loss: 0.0271 - accuracy: 0.9915
# Epoch 00008: accuracy improved from 0.99022 to 0.99136, saving model to models\LSTM.h5
# 83/83 [==============================] - 2s 19ms/step - loss: 0.0273 - accuracy: 0.9914
# Epoch 9/10
# 81/83 [============================>.] - ETA: 0s - loss: 0.0227 - accuracy: 0.9932
# Epoch 00009: accuracy improved from 0.99136 to 0.99298, saving model to models\LSTM.h5
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0233 - accuracy: 0.9930
# Epoch 10/10
# 80/83 [===========================>..] - ETA: 0s - loss: 0.0207 - accuracy: 0.9940
# Epoch 00010: accuracy improved from 0.99298 to 0.99421, saving model to models\LSTM.h5
# 83/83 [==============================] - 1s 18ms/step - loss: 0.0204 - accuracy: 0.9942

# %% [markdown]
# <hr>
#
# ### Testing
# To evaluate the model, we need to predict the sentiment using our <b>x_test</b> data and comparing the predictions with <b>y_test</b> (expected output) data. Then, we calculate the accuracy of the model by dividing numbers of correct prediction with the total data. Resulted an accuracy of <b>86.63%</b>

# %%
# y_pred = model.predict_classes(x_test, batch_size = 128)

predict_x = model.predict(x_test, batch_size = 128) 
y_pred = np.argmax(predict_x,axis=1)

true = 0
for i, y in enumerate(y_test):
    if y == y_pred[i]:
        true += 1

print('Correct Prediction: {}'.format(true))
print('Wrong Prediction: {}'.format(len(y_pred) - true))
print('Accuracy: {}'.format(true/len(y_pred)*100))
# Out:
# Correct Prediction: 1523
# Wrong Prediction: 1111
# Accuracy: 57.82080485952923

# %% [markdown]
# ---
#
# ### Load Saved Model
#
# Load saved model and use it to predict a tweet statement's sentiment (positive or negative).

# %%
loaded_model = load_model('models/LSTM.h5')

# %% [markdown]
# Receives a tweet as an input to be predicted

# %%
tweet = str(input('Tweet: '))
# Out:
# Tweet: Pendaftaran Capres untuk #Pilpres2019 saja belum dibuka sampai Agustus 2018...yang normatif begini politikus PDIP masih belum paham? #2019GantiPresiden

# %% [markdown]
# The input must be pre processed before it is passed to the model to be predicted

# %%
# Pre-process input
regex = re.compile(r'[^a-zA-Z\s]')
tweet = regex.sub('', tweet)
print('Cleaned: ', tweet)

words = tweet.split(' ')
filtered = [w for w in words if w not in indonesian_stopwords]
filtered = ' '.join(filtered)
filtered = [tweet.lower()]

print('Filtered: ', filtered)
# Out:
# Cleaned:  Pendaftaran Capres untuk Pilpres saja belum dibuka sampai Agustus yang normatif begini politikus PDIP masih belum paham GantiPresiden
# Filtered:  ['pendaftaran capres untuk pilpres saja belum dibuka sampai agustus yang normatif begini politikus pdip masih belum paham gantipresiden']

# %% [markdown]
# Once again, we need to tokenize and encode the words. I use the tokenizer which was previously declared because we want to encode the words based on words that are known by the model.

# %%
tokenize_words = token.texts_to_sequences(filtered)
tokenize_words = pad_sequences(tokenize_words, maxlen=get_max_length(), padding='post', truncating='post')
print(tokenize_words)
# Out:
# [[ 6444   591   589   319  1764   827  1788  1237  6436    67 22004  2255]]

# %% [markdown]
# This is the result of the prediction which shows the **confidence score** of the tweet statement.

# %%
result = loaded_model.predict(tokenize_words)
print(result)
# Out:
# [[0.96300685]]

# %% [markdown]
# If the confidence score is close to 0, then the statement is **negative**. On the other hand, if the confidence score is close to 1, then the statement is **positive**. I use a threshold of **0.7** to determine which confidence score is positive and negative, so if it is equal or greater than 0.7, it is **positive** and if it is less than 0.7, it is **negative**

# %%
if result >= 0.7:
    print('positive')
else:
    print('negative')
# Out:
# positive

# %%
tokenizer_json = token.to_json()
with io.open('tokenizer.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(tokenizer_json, ensure_ascii=False))
